# %%
import pandas as pd

# %%
df_top_singles = pd.read_csv('df_top_singles.csv')

# %%
df_top_singles
# Out:
#       année  rang                          artiste  \
# 0      1994     1  N'DOUR, YOUSSOU & CHERRY, NENEH
# 1      1994     2                             I AM
# 2      1994     3      REEL 2 REAL & STUNTMAN, MAD
# 3      1994     4                      RED, AXELLE
# 4      1994     5               SPRINGSTEEN, BRUCE
# ...     ...   ...                              ...
# 4344   2024   196                    BILLIE EILISH
# 4345   2024   197                    JÉRÉMY FREROT
# 4346   2024   198                           NEKFEU
# 4347   2024   199                    ARIANA GRANDE
# 4348   2024   200                              PLK
#
#                                          titre              id_spotify
# 0                                    7 SECONDS                   no id
# 1                              JE DANSE LE MIA                   no id
# 2                               I LIKE TO MOVE                   no id
# ...

# %%
df_top_singles["artist_name_clean"] = df_top_singles["artist_name"].str.title()

# %%
df_top_singles.head(2)
# Out:
#                                           Unnamed: 0   année  rang  \
# 0  0,1994,1,"N'DOUR, YOUSSOU & CHERRY, NENEH",7 S...     NaN   NaN
# 1                                                  1  1994.0   2.0
#
#   artist_name            titre id_spotify; artist_name_clean
# 0         NaN              NaN         NaN               NaN
# 1        I AM  JE DANSE LE MIA      no id;              I Am
